# %%
pip install xarray
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.1 MB 1.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.4/1.1 MB 5.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.0/1.1 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 7.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install netcdf4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/6.6 MB 1.7 MB/s eta 0:00:04
#    --- ------------------------------------ 0.6/6.6 MB 9.9 MB/s eta 0:00:01
#    ------- -------------------------------- 1.3/6.6 MB 12.0 MB/s eta 0:00:01
#    -------- ------------------------------- 1.5/6.6 MB 8.6 MB/s eta 0:00:01
#    ------------ --------------------------- 2.1/6.6 MB 9.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.8/6.6 MB 11.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.7/6.6 MB 12.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.8/6.6 MB 14.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.7/6.6 MB 15.1 MB/s eta 0:00:01
#    ---------------------------------------  6.5/6.6 MB 15.5 MB/s eta 0:00:01
# ...

# %%
import xarray as xr

# %%
ds=xr.open_dataset('https://thredds.rda.ucar.edu/thredds/dodsC/aggregations/g/ds633.1/2/TP', engine='netcdf4')

# %%
ds
# Out:
# <xarray.Dataset> Size: 169GB
# Dimensions:                                                                                             (
#                                                                                                          lat: 721,
#                                                                                                          lon: 1440,
#                                                                                                          time: 516,
#                                                                                                          layer_between_two_depths_below_surface_layer: 1,
#                                                                                                          layer_between_two_depths_below_surface_layer1: 1,
#                                                                                                          ...
# ...

# %%
#Eastern Pacific SST
ds['Sea_surface_temperature_surface_Mixed_intervals_Average'].sel(lon=360-95., lat=5., method='nearest').plot()
